# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('mumbai.csv')

# %%
df.columns
# Out:
# Index(['name', 'latitude', 'longitude', 'datetime', 'tempmax', 'tempmin',
#        'temp', 'feelslikemax', 'feelslikemin', 'feelslike', 'dew', 'humidity',
#        'precip', 'precipprob', 'precipcover', 'preciptype', 'winddir',
#        'sealevelpressure', 'cloudcover', 'visibility', 'severerisk',
#        'moonphase', 'conditions', 'description'],
#       dtype='object')

# %%
df = df[['latitude', 'longitude', 'tempmax', 'tempmin',
       'temp','feelslike', 'dew', 'humidity',
       'precip', 'precipprob', 'winddir',
       'visibility', 'conditions']]

# %%
df
# Out:
#      latitude  longitude  tempmax  tempmin  temp  feelslike   dew  humidity  \
# 0       18.94     72.835     31.3     19.3  25.0       25.1  16.0      58.9
# 1       18.94     72.835     28.9     17.9  24.4       24.5  15.1      57.3
# 2       18.94     72.835     30.6     19.1  25.0       25.3  18.9      70.3
# 3       18.94     72.835     30.6     19.1  25.2       25.5  18.9      69.8
# 4       18.94     72.835     30.7     20.7  25.2       25.4  17.6      64.3
# ..        ...        ...      ...      ...   ...        ...   ...       ...
# 995     18.94     72.835     28.0     25.9  26.7       29.0  25.8      95.0
# 996     18.94     72.835     28.0     24.9  26.0       26.7  25.7      98.2
# 997     18.94     72.835     30.2     24.9  27.4       31.3  25.8      91.6
# 998     18.94     72.835     30.0     26.0  28.0       32.8  25.6      86.9
# 999     18.94     72.835     31.6     26.9  29.0       33.5  24.2      75.7
#
# ...
